# %%
# Importing the Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
# Encoding categorical variables
dataset = pd.get_dummies(dataset, drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
# Separate independent and dependent variables
indep = dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep = dataset['charges']

# %%
# Importing necessary libraries
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

# Define parameter grid
param_grid = {'kernel': ['rbf', 'poly', 'sigmoid'],
              'C': [10, 100, 1000],
              'gamma': ['auto', 'scale']}

# Create GridSearchCV object
grid = GridSearchCV(SVR(), param_grid, refit=True, verbose=3, n_jobs=-1, cv=3)

# Fit the model
grid.fit(indep, dep)

# Print best parameters
print("Best parameters:", grid.best_params_)
# Out:
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# [CV 2/3] END .....C=10, gamma=auto, kernel=poly;, score=0.835 total time=33.5min
# [CV 1/3] END C=1000, gamma=auto, kernel=sigmoid;, score=-0.124 total time=   0.1s
# [CV 2/3] END C=1000, gamma=auto, kernel=sigmoid;, score=-0.073 total time=   0.1s
# [CV 3/3] END C=1000, gamma=auto, kernel=sigmoid;, score=-0.116 total time=   0.1s
# [CV 1/3] END ..C=1000, gamma=scale, kernel=rbf;, score=-0.142 total time=   0.2s
# [CV 2/3] END ..C=1000, gamma=scale, kernel=rbf;, score=-0.098 total time=   0.2s
# [CV 3/3] END ..C=1000, gamma=scale, kernel=rbf;, score=-0.203 total time=   0.2s
# [CV 1/3] END .C=1000, gamma=scale, kernel=poly;, score=-0.075 total time=   0.1s
# [CV 2/3] END .C=1000, gamma=scale, kernel=poly;, score=-0.057 total time=   0.1s
# [CV 3/3] END .C=1000, gamma=scale, kernel=poly;, score=-0.149 total time=   0.1s
# [CV 1/3] END C=1000, gamma=scale, kernel=sigmoid;, score=-1.636 total time=   0.1s
# [CV 2/3] END C=1000, gamma=scale, kernel=sigmoid;, score=-1.642 total time=   0.1s
# [CV 3/3] END C=1000, gamma=scale, kernel=sigmoid;, score=-1.479 total time=   0.1s
# [CV 1/3] END .....C=10, gamma=auto, kernel=rbf;, score=-0.122 total time=   0.3s
# [CV 3/3] END ....C=10, gamma=scale, kernel=rbf;, score=-0.127 total time=   0.2s
# [CV 1/3] END ....C=100, gamma=auto, kernel=rbf;, score=-0.113 total time=   0.2s
# [CV 3/3] END ....C=100, gamma=auto, kernel=poly;, score=0.686 total time=33.9min
# [CV 3/3] END .....C=10, gamma=auto, kernel=poly;, score=0.792 total time=23.3min
# [CV 3/3] END .C=1000, gamma=auto, kernel=poly;, score=-14.434 total time=18.1min
# [CV 2/3] END .C=10, gamma=auto, kernel=sigmoid;, score=-0.073 total time=   0.1s
# [CV 1/3] END ....C=10, gamma=scale, kernel=rbf;, score=-0.121 total time=   0.3s
# [CV 3/3] END ...C=10, gamma=scale, kernel=poly;, score=-0.180 total time=   0.1s
# [CV 2/3] END ....C=100, gamma=auto, kernel=rbf;, score=-0.064 total time=   0.2s
# [CV 1/3] END C=100, gamma=auto, kernel=sigmoid;, score=-0.124 total time=   0.1s
# [CV 3/3] END C=100, gamma=auto, kernel=sigmoid;, score=-0.116 total time=   0.1s
# [CV 2/3] END ...C=100, gamma=scale, kernel=rbf;, score=-0.095 total time=   0.3s
# [CV 1/3] END ..C=100, gamma=scale, kernel=poly;, score=-0.122 total time=   0.1s
# [CV 2/3] END ..C=100, gamma=scale, kernel=poly;, score=-0.101 total time=   0.1s
# [CV 1/3] END C=100, gamma=scale, kernel=sigmoid;, score=-0.152 total time=   0.1s
# [CV 3/3] END C=100, gamma=scale, kernel=sigmoid;, score=-0.138 total time=   0.2s
# [CV 2/3] END ...C=1000, gamma=auto, kernel=rbf;, score=-0.037 total time=   0.4s
# [CV 1/3] END .C=1000, gamma=auto, kernel=poly;, score=-33.573 total time=44.1min
# [CV 1/3] END .....C=10, gamma=auto, kernel=poly;, score=0.842 total time=47.1min
# [CV 3/3] END .....C=10, gamma=auto, kernel=rbf;, score=-0.116 total time=   0.3s
# [CV 1/3] END ...C=10, gamma=scale, kernel=poly;, score=-0.117 total time=   0.1s
# [CV 2/3] END C=10, gamma=scale, kernel=sigmoid;, score=-0.075 total time=   0.2s
# [CV 3/3] END ....C=100, gamma=auto, kernel=rbf;, score=-0.112 total time=   0.2s
# [CV 2/3] END C=100, gamma=auto, kernel=sigmoid;, score=-0.073 total time=   0.1s
# [CV 1/3] END ...C=100, gamma=scale, kernel=rbf;, score=-0.148 total time=   0.2s
# [CV 3/3] END ...C=100, gamma=scale, kernel=rbf;, score=-0.201 total time=   0.2s
# [CV 3/3] END ..C=100, gamma=scale, kernel=poly;, score=-0.192 total time=   0.1s
# [CV 2/3] END C=100, gamma=scale, kernel=sigmoid;, score=-0.104 total time=   0.1s
# [CV 1/3] END ...C=1000, gamma=auto, kernel=rbf;, score=-0.090 total time=   0.5s
# [CV 3/3] END ...C=1000, gamma=auto, kernel=rbf;, score=-0.131 total time=   0.4s
# [CV 2/3] END ..C=1000, gamma=auto, kernel=poly;, score=-7.258 total time=48.2min
# [CV 1/3] END .C=10, gamma=auto, kernel=sigmoid;, score=-0.124 total time=   0.1s
# [CV 3/3] END .C=10, gamma=auto, kernel=sigmoid;, score=-0.116 total time=   0.1s
# [CV 2/3] END ...C=10, gamma=scale, kernel=poly;, score=-0.084 total time=   0.1s
# [CV 1/3] END C=10, gamma=scale, kernel=sigmoid;, score=-0.126 total time=   0.2s
# [CV 1/3] END ...C=100, gamma=auto, kernel=poly;, score=0.802 total time=118.1min
# [CV 2/3] END .....C=10, gamma=auto, kernel=rbf;, score=-0.072 total time=   0.3s
# [CV 2/3] END ....C=10, gamma=scale, kernel=rbf;, score=-0.062 total time=   0.3s
# [CV 3/3] END C=10, gamma=scale, kernel=sigmoid;, score=-0.118 total time=   0.1s
# [CV 2/3] END ...C=100, gamma=auto, kernel=poly;, score=0.732 total time=119.0min
# Best parameters: {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}

# %%
# print best parameter after tuning 
re=grid.cv_results_

print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.144658      0.004599         0.130463        0.004199      10
# 1     2077.723882    585.111359         0.046734        0.009342      10
# 2        0.091982      0.000782         0.041814        0.005964      10
# 3        0.122326      0.004530         0.130770        0.001675      10
# 4        0.097044      0.001810         0.033605        0.004935      10
# 5        0.109594      0.005192         0.049066        0.006202      10
# 6        0.119939      0.006663         0.125036        0.006750     100
# 7     5419.485103   2395.330940         0.048858        0.009321     100
# 8        0.078878      0.003652         0.035267        0.005743     100
# 9        0.102668      0.011942         0.137624        0.018626     100
# 10       0.095694      0.008872         0.028944        0.000908     100
# 11       0.109192      0.009760         0.065873        0.041044     100
# 12       0.289204      0.051232         0.154852        0.036857    1000
# 13    2208.143536    800.720181         0.025269        0.003467    1000
# 14       0.066392      0.001408         0.026309        0.000266    1000
# 15       0.088240      0.002639         0.094372        0.000396    1000
# 16       0.099765      0.003432         0.027674        0.002971    1000
# 17       0.087758      0.006325         0.038233        0.002723    1000
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto         poly
# 2         auto      sigmoid
# 3        scale          rbf
# 4        scale         poly
# 5        scale      sigmoid
# 6         auto          rbf
# 7         auto         poly
# 8         auto      sigmoid
# 9        scale          rbf
# 10       scale         poly
# 11       scale      sigmoid
# 12        auto          rbf
# 13        auto         poly
# 14        auto      sigmoid
# 15       scale          rbf
# 16       scale         poly
# 17       scale      sigmoid
#
#                                                params  split0_test_score  \
# 0         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}          -0.121859
# 1        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.841561
# 2     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.124306
# 3        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}          -0.120647
# 4       {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}          -0.117169
# 5    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.126045
# 6        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}          -0.113010
# 7       {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.802160
# 8    {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.124306
# 9       {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}          -0.147772
# 10     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}          -0.122152
# 11  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.151746
# 12      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}          -0.090261
# 13     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}         -33.573194
# 14  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.124306
# 15     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}          -0.141802
# 16    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}          -0.074574
# 17  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...          -1.636325
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0           -0.071812          -0.115978        -0.103216        0.022336
# 1            0.835473           0.792087         0.823040        0.022028
# 2           -0.073333          -0.116351        -0.104664        0.022391
# 3           -0.062407          -0.126932        -0.103329        0.029050
# 4           -0.084321          -0.180189        -0.127226        0.039778
# 5           -0.075274          -0.117573        -0.106297        0.022208
# 6           -0.064058          -0.111684        -0.096251        0.022770
# 7            0.732073           0.685501         0.739911        0.047947
# 8           -0.073333          -0.116351        -0.104664        0.022391
# 9           -0.094747          -0.201098        -0.147873        0.043418
# 10          -0.100605          -0.191723        -0.138160        0.038883
# 11          -0.103873          -0.138200        -0.131273        0.020148
# 12          -0.036964          -0.131036        -0.086087        0.038518
# 13          -7.258326         -14.434043       -18.421854       11.106906
# 14          -0.073333          -0.116351        -0.104664        0.022391
# 15          -0.098386          -0.202734        -0.147641        0.042799
# 16          -0.057414          -0.149167        -0.093719        0.039829
# 17          -1.642364          -1.478968        -1.585886        0.075642
#
#     rank_test_score
# 0                 6
# 1                 1
# 2                 8
# 3                 7
# 4                12
# 5                11
# 6                 5
# 7                 2
# 8                 8
# 9                16
# 10               14
# 11               13
# 12                3
# 13               18
# 14                8
# 15               15
# 16                4
# 17               17

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:34
# BMI:22
# Children:2
# Sex Male 0 or 1:0
# Smoker Yes 0 or 1:0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[5640.38796943]
# /Users/mani/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
